# %%
import numpy as np
import pandas as pd



variable = pd.read_csv("Melde_Test.csv")           #Importing csv File
New = variable.to_numpy()                          #Converting it to array

#Defining Columns in csv file a arrays to perform operations

P_Tr = variable["P_Tr"]                            #No of loops in transverse motion
L_Tr = variable["L_Tr"]                            #Length of one loop for transverse motion
Load_Tr = variable["Load_Tr"]                      #Load in transverse motion

P_Long = variable["P_Long"]                         #No of loops in Longitudinal motion
L_Long = variable["L_Long"]                         #Length of one loop for Longitudinal motion
Load_Long = variable["Load_Long"]                   #Load in Longitudinal motion
m = variable["mass_per_unit_length"]
g = variable["g"]                                   #Acceleration due to gravity
M_Pan = variable["M_Pan"]                           #Mass of Pan

#Solve for Transverse motion
if len(P_Tr) == len(L_Tr):
    for i in range(len(L_Tr)):
        L_one_Loop = (L_Tr/P_Tr)                     #Length of one loop 
        Tension_Tr = ((Load_Tr + M_Pan)*g )          #Tension
    Fr_Tr = (1/L_one_Loop)*np.sqrt(Tension_Tr/m)
    #print(Tension_Tr)
    #print(L_one_Loop)
    print("Average Frequency of Transverse motion = ",((np.sum(Fr_Tr_2))/len(P_Tr)))



#Solve for Transverse motion
if len(P_Long) == len(L_Long):
    for i in range(len(L_Long)):
        L_one_Loop = (L_Long/P_Long)                            #Length of one loop 
        Tension_Long = ((Load_Long + M_Pan)*g )                 #Tension
    Fr_Long = np.sqrt(Tension_Long/m)*(1/(2*L_one_Loop))
    #print(Tension_Long)
    #print(L_one_Loop)
    
    print("Average Frequency of Longitudinal Wave = ",(np.sum(Fr_Long)/len(L_Long)))
# Out:
# Average Frequency of Transverse motion =  123.75366935439527
# Average Frequency of Longitudinal Wave =  30.864311364599782

# %%
import numpy as np
import pandas as pd



variable = pd.read_csv("Melde_Test.csv")
New = variable.to_numpy()
'''
Tr_Tension = variable["Tr_Tension"]
Tr_len_loop = variable["Tr_len_loop"]
Long_Tension = variable["Long_Tension"]
Long_len_loop = variable["Long_len_loop"]
'''
P_Tr = variable["P_Tr"]                         #No of loops in transverse motion
L_Tr = variable["L_Tr"]                         #Length of one loop for transverse motion
Load_Tr = variable["Load_Tr"]                   #Load in transverse motion

P_Long = variable["P_Long"]                         #No of loops in Longitudinal motion
L_Long = variable["L_Long"]                         #Length of one loop for Longitudinal motion
Load_Long = variable["Load_Long"]                   #Load in Longitudinal motion
m = variable["mass_per_unit_length"]
g = variable["g"]
M_Pan = variable["M_Pan"]                      #Mass of Pan
'''
#Solve for Transverse motion
if len(P_Tr) == len(L_Tr):
    for i in range(len(L_Tr)):
        L_one_Loop = (L_Tr/P_Tr)                            #Length of one loop 
        Tension_Tr = ((Load_Tr + M_Pan)*g )                 #Tension
    Fr_Tr = (1/L_one_Loop)            #Frequency 
    Fr_Tr_1 = np.sqrt(Tension_Tr/m)
    Fr_Tr_2 = (1/L_one_Loop)*np.sqrt(Tension_Tr/m)
    print(Tension_Tr)
    print(L_one_Loop)
    print(Fr_Tr)
    print(Fr_Tr_1)
    print(Fr_Tr_2)
    print(np.sum(Fr_Tr_2))
    #print("Average Frequency of Transverse motion = ",((np.sum(Fr_Tr_2))/len(P_Tr)))
'''


#Solve for Transverse motion
if len(P_Long) == len(L_Long):
    for i in range(len(L_Long)):
        L_one_Loop = (L_Long/P_Long)                            #Length of one loop 
        Tension_Long = ((Load_Long + M_Pan)*g )                 #Tension
    #Fr_Long = (1/L_one_Loop)*np.sqrt(Tension_Long/m)            #Frequency 
   
    
    #print(Tension_Tr)
    #print(L_one_Loop)
    Fr_Long_1 = np.sqrt(Tension_Long/m)
    Fr_Long_2 = (1/(2*L_one_Loop))
    Fr_Long_3 = np.sqrt(Tension_Long/m)*(1/(2*L_one_Loop))
    print(Tension_Long)
    print(L_one_Loop)
    #print(Fr_Long)        
    #print(Fr_Long_1)
    #print(Fr_Long_2)
    
    print((Fr_Long_3))
    #print("Average Frequency of Transverse motion = ",((np.sum(Fr_Tr_2))/len(P_Tr)))

    #print("Average Frequency of Transverse motion = ",((np.sum(Fr_Long))/len(P_Long)))
# Out:
# 0    196098.0
# 1    294098.0
# 2    392098.0
# 3    490098.0
# 4    588098.0
# 5    686098.0
# 6    784098.0
# dtype: float64
# 0    10.650000
# 1    10.900000
# 2    15.100000
# 3    16.140000
# 4    16.433333
# 5    20.242857
# 6    21.587500
# dtype: float64
# 0    29.475081
# 1    35.268547
# 2    29.396011
# 3    30.747228
# 4    33.080131
# 5    29.006097
# 6    29.077084
# dtype: float64
